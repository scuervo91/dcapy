# %%
import os

from dcapy import dca
from dcapy.models import CashFlow, ChgPts, CashFlowModel, Period, Scenario

import numpy as np 
import pandas as pd
from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns 
from scipy import stats
import seaborn as sns

# %%
p1_dict = {
    'name':'pdp',
    'dca': {
        'ti':'2021-01-01',
        'bsw':0.3,
        'slope':[2e-5,1e-5],
        'fluid_rate':1000,
        'gor':0.3
    },
    'start':'2021-01-01',
    'end':'2021-01-10',
    'freq_input':'D',
    'freq_output':'D',
    'cashflow_params':[
            {
                'name':'fix_opex',
                'const_value':-5000,
                'target':'opex',
            },
            {
                'name':'var_opex',
                'const_value':-5,
                'target':'opex',
                'multiply':'oil_volume'
            },
            {
                'name':'income',
                'const_value':60,
                'target':'income',
                'multiply':'oil_volume'
            }
        ]
}

p1 = Period(**p1_dict)
p1
# Out:
# Period(name='pdp', dca=Wor(bsw=0.3, slope=[2e-05, 1e-05], fluid_rate=1000.0, ti=datetime.date(2021, 1, 1), seed=None, gor=0.3, glr=None), start=datetime.date(2021, 1, 1), end=datetime.date(2021, 1, 10), time_list=None, freq_input='D', freq_output='D', rate_limit=None, cum_limit=None, iter=1, ppf=None, cashflow_params=[CashFlowParams(name='fix_opex', iter=1, const_value=-5000.0, periods=None, array_values=None, target='opex', multiply=None, agg='sum', wi=1, depends=False), CashFlowParams(name='var_opex', iter=1, const_value=-5.0, periods=None, array_values=None, target='opex', multiply='oil_volume', agg='sum', wi=1, depends=False), CashFlowParams(name='income', iter=1, const_value=60.0, periods=None, array_values=None, target='income', multiply='oil_volume', agg='sum', wi=1, depends=False)], cashflow=None, depends=None, forecast=None)

# %%
f1 = p1.generate_forecast()
f1
# Out:
#               oil_rate  water_rate      oil_cum    water_cum       bsw  \
# date
# 2021-01-01  700.000000  300.000000   700.000000   300.000000  0.300000
# 2021-01-02  697.051793  302.948207  1397.051793   602.948207  0.302948
# 2021-01-03  694.099795  305.900205  2091.151588   908.848412  0.305900
# 2021-01-04  691.144380  308.855620  2782.295968  1217.704032  0.308856
# 2021-01-05  688.185924  311.814076  3470.481893  1529.518107  0.311814
# 2021-01-06  685.224799  314.775201  4155.706692  1844.293308  0.314775
# 2021-01-07  682.261376  317.738624  4837.968068  2162.031932  0.317739
# 2021-01-08  679.296024  320.703976  5517.264092  2482.735908  0.320704
# 2021-01-09  676.329110  323.670890  6193.593202  2806.406798  0.323671
# 2021-01-10  673.360998  326.639002  6866.954200  3133.045800  0.326639
# 2021-01-01  700.000000  300.000000   700.000000   300.000000  0.300000
# 2021-01-02  698.527945  301.472055  1398.527945   601.472055  0.301472
# ...

# %%
p1.forecast.df()['gas_rate'].values
# Out:
# array([210.        , 209.11553795, 208.22993843, 207.3433141 ,
#        206.45577727, 205.56743975, 204.67841284, 203.78880723,
#        202.89873299, 202.00829946, 210.        , 209.55838354,
#        209.11647051, 208.67427499, 208.23181101, 207.7890926 ,
#        207.34613377, 206.90294847, 206.45955066, 206.01595423])

# %%
fig, ax = plt.subplots()
sns.lineplot(data=f1,x='oil_cum',y='wor', hue='iteration',ax=ax)
ax.set_yscale('log')

# %%
sns.lineplot(data=f1,x=f1.index.to_timestamp(),y='oil_rate', hue='iteration')
# Out:
# <AxesSubplot:xlabel='date', ylabel='oil_rate'>

# %%
c1=p1.generate_cashflow()

# %%
p1.cashflow[0].fcf()
# Out:
#                   income  total_income  fix_opex     var_opex   total_opex  \
# 2021-01-01  41823.107590  41823.107590   -5000.0 -3485.258966 -8485.258966
# 2021-01-02  41734.547638  41734.547638   -5000.0 -3477.878970 -8477.878970
# 2021-01-03  41557.325253  41557.325253   -5000.0 -3463.110438 -8463.110438
# 2021-01-04  41379.909138  41379.909138   -5000.0 -3448.325761 -8448.325761
# 2021-01-05  41202.321703  41202.321703   -5000.0 -3433.526809 -8433.526809
# 2021-01-06  41024.585259  41024.585259   -5000.0 -3418.715438 -8418.715438
# 2021-01-07  40846.722007  40846.722007   -5000.0 -3403.893501 -8403.893501
# 2021-01-08  40668.754022  40668.754022   -5000.0 -3389.062835 -8389.062835
# 2021-01-09  40490.703245  40490.703245   -5000.0 -3374.225270 -8374.225270
# 2021-01-10  40401.659893  40401.659893   -5000.0 -3366.804991 -8366.804991
#
#             total_capex           fcf        cum_fcf
# 2021-01-01            0  33337.848625   33337.848625
# ...

# %%
p1.cashflow[1].npv([0.05,0.1,0.15])
# Out:
#                 npv
# 0.05  268573.751573
# 0.10  224088.104359
# 0.15  191501.855928

# %%
p1.cashflow[1].irr()
# Out:
# nan

# %%
bsw = 0.5
slope = [3.5e-6,3e-6,4e-6]
ti =  date(2021,1,1)

w1 = dca.Wor(bsw=bsw,slope=slope,ti=ti, glr=0.3, fluid_rate = 1000,)

data1 = dict(
    start = date(2021,1,1),
    end = date(2025,1,1),
    freq_input = 'D',
    freq_output = 'D',
    rate_limit = 80,
)

fw1=w1.forecast(**data1)

data2 = dict(
    start = date(2021,1,1),
    end = date(2025,1,1),
    freq_input = 'D',
    freq_output = 'M',
    rate_limit = 80,
)

fw2=w1.forecast(**data2)

data3 = dict(
    start = date(2021,1,1),
    end = date(2025,1,1),
    freq_input = 'D',
    freq_output = 'A',
    rate_limit = 80,
)

fw3=w1.forecast(**data3)

fig, ax = plt.subplots(figsize=(10,10))

sns.lineplot(data=fw1,x=fw1.index.to_timestamp(),y='oil_rate', hue='iteration', ax=ax)

sns.scatterplot(data=fw2,x=fw2.index.to_timestamp(),y='oil_rate', hue='iteration', ax=ax)

sns.scatterplot(data=fw3,x=fw3.index.to_timestamp(),y='oil_rate', hue='iteration', ax=ax)
# Out:
# <AxesSubplot:xlabel='date', ylabel='oil_rate'>

# %%
fw3.head(31)
# Out:
#       iteration    oil_rate  water_rate        oil_cum  gas_rate  \
# date
# 2021          0  429.035826  570.964174  156598.076477     300.0
# 2021          1  438.121632  561.878368  159914.395636     300.0
# 2021          2  420.283007  579.716993  153403.297601     300.0
# 2022          0  319.030868  680.969132  273044.343471     300.0
# 2022          1  338.441047  661.558953  283445.377769     300.0
# 2022          2  301.318708  698.681292  263384.626114     300.0
# 2023          0  246.592877  753.407123  363050.743523     300.0
# 2023          1  268.801908  731.198092  381558.074114     300.0
# 2023          2  227.303406  772.696594  346350.369169     300.0
# 2024          0  197.858163  802.141837  435466.831360     300.0
# 2024          1  219.704959  780.295041  461970.089229     300.0
# 2024          2  179.556443  820.443557  412068.027257     300.0
# 2025          0  178.853587  821.146413  435645.684947     300.0
# ...

# %%
fw2
# Out:
#          iteration    oil_rate  water_rate        oil_cum  gas_rate  \
# date
# 2021-01          0  493.493421  506.506579   15298.296047     300.0
# 2021-01          1  494.416044  505.583956   15326.897353     300.0
# 2021-01          2  492.573111  507.426889   15269.766446     300.0
# 2021-02          0  480.919285  519.080715   28764.036017     300.0
# 2021-02          1  483.597121  516.402879   28867.616743     300.0
# ...            ...         ...         ...            ...       ...
# 2024-12          1  201.612342  798.387658  461970.089229     300.0
# 2024-12          2  162.754724  837.245276  412068.027257     300.0
# 2025-01          0  178.853587  821.146413  435645.684947     300.0
# 2025-01          1  200.061462  799.938538  462170.150691     300.0
# 2025-01          2  161.342616  838.657384  412229.369872     300.0
#
#             water_cum       bsw       wor     wor_1  delta_time  fluid_rate  \
# date
# ...

# %%
p2_dict = {
    'name':'pdp',
    'dca': {
        'ti':0,
        'bsw':0.3,
        'slope':[2e-5,1e-5],
        'fluid_rate':1000,
        'gor':0.3
    },
    'start':0,
    'end':20,
    'freq_input':'D',
    'freq_output':'D',
    'cashflow_params':[
            {
                'name':'fix_opex',
                'const_value':-5000,
                'target':'opex',
            },
            {
                'name':'var_opex',
                'const_value':-5,
                'target':'opex',
                'multiply':'oil_volume'
            },
            {
                'name':'income',
                'const_value':60,
                'target':'income',
                'multiply':'oil_volume'
            }
        ]
}

p2 = Period(**p2_dict)
p2
# Out:
# Period(name='pdp', dca=Wor(bsw=0.3, slope=[2e-05, 1e-05], fluid_rate=1000.0, ti=0, seed=None, gor=0.3, glr=None), start=0, end=20, time_list=None, freq_input='D', freq_output='D', rate_limit=None, cum_limit=None, iter=1, ppf=None, cashflow_params=[CashFlowParams(name='fix_opex', iter=1, const_value=-5000.0, periods=None, array_values=None, target='opex', multiply=None, agg='sum', wi=1, depends=False), CashFlowParams(name='var_opex', iter=1, const_value=-5.0, periods=None, array_values=None, target='opex', multiply='oil_volume', agg='sum', wi=1, depends=False), CashFlowParams(name='income', iter=1, const_value=60.0, periods=None, array_values=None, target='income', multiply='oil_volume', agg='sum', wi=1, depends=False)], cashflow=None, depends=None, forecast=None)

# %%
p2.generate_forecast()
# Out:
#         oil_rate  water_rate       oil_cum    water_cum       bsw       wor  \
# date
# 0     700.000000  300.000000    700.000000   300.000000  0.300000  0.428571
# 1     697.051793  302.948207   1397.051793   602.948207  0.302948  0.434614
# 2     694.099795  305.900205   2091.151588   908.848412  0.305900  0.440715
# 3     691.144380  308.855620   2782.295968  1217.704032  0.308856  0.446876
# 4     688.185924  311.814076   3470.481893  1529.518107  0.311814  0.453096
# 5     685.224799  314.775201   4155.706692  1844.293308  0.314775  0.459375
# 6     682.261376  317.738624   4837.968068  2162.031932  0.317739  0.465714
# 7     679.296024  320.703976   5517.264092  2482.735908  0.320704  0.472112
# 8     676.329110  323.670890   6193.593202  2806.406798  0.323671  0.478570
# 9     673.360998  326.639002   6866.954200  3133.045800  0.326639  0.485087
# 10    670.392051  329.607949   7537.346251  3462.653749  0.329608  0.491664
# ...

# %%
time1 = np.arange(0,10,1)
qi1 = 500,
slope = 3e-6
bswi = 0.5
wori = dca.bsw_to_wor(bswi)
fluid_rate = [5000]*10
f1 = dca.wor_forecast(time1,fluid_rate,slope,wori, rate_limit=None, wor_limit=None, cum_limit=1e5)
f1.to_csv('wor_test_1.csv')

# %%
bsw = 0.5
slope = [3.5e-6,3e-6,4e-6]
ti =  date(2021,1,1)
w1 = dca.Wor(bsw=bsw,slope=slope,ti=ti, glr=0.3, fluid_rate = 1000,)
data = dict(
    start = date(2021,1,1),
    end = date(2021,1,10),
    freq_input = 'D',
    freq_output = 'D',
    rate_limit = 480,
)
#print(w1.forecast(**data))
f1 = w1.forecast(**data)
f1
# Out:
#               oil_rate  water_rate      oil_cum    water_cum       bsw  \
# date
# 2021-01-01  500.000000  500.000000   500.000000   500.000000  0.500000
# 2021-01-02  499.562500  500.437500   999.562500  1000.437500  0.500437
# 2021-01-03  499.125384  500.874616  1498.687884  1501.312116  0.500875
# 2021-01-04  498.688651  501.311349  1997.376535  2002.623465  0.501311
# 2021-01-05  498.252303  501.747697  2495.628838  2504.371162  0.501748
# 2021-01-06  497.816339  502.183661  2993.445176  3006.554824  0.502184
# 2021-01-07  497.380759  502.619241  3490.825936  3509.174064  0.502619
# 2021-01-08  496.945565  503.054435  3987.771501  4012.228499  0.503054
# 2021-01-09  496.510757  503.489243  4484.282258  4515.717742  0.503489
# 2021-01-10  496.076334  503.923666  4980.358591  5019.641409  0.503924
# 2021-01-01  500.000000  500.000000   500.000000   500.000000  0.500000
# 2021-01-02  499.625000  500.375000   999.625000  1000.375000  0.500375
# ...

# %%
f1.to_csv('wor_test_2.csv')
