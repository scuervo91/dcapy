# %%
import os
path = os.path.abspath(os.path.join('..'))
print(path)
import sys
sys.path.insert(0,path)
from dcapy.weiner import Weiner
import numpy as np 
import pandas as pd
from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns 
from scipy import stats
# Out:
# /home/scuervo91/dev/dcapy

# %%
x = Weiner()

df = x.brownian_motion(100,5)
fig, ax = plt.subplots()
df.plot(ax=ax)
# Out:
# <AxesSubplot:>

# %%
x2 = Weiner(initial_condition=0,generator=stats.bernoulli, mu=0.0, kw_generator={'loc':0},arg_generator=[0.05],freq_mu='A', seed=9)

# %%
df2 = x2.brownian_motion(10,3, freq='A')

# %%
df2.plot()
# Out:
# <AxesSubplot:>

# %%
df2.diff()
# Out:
#      0    1    2
# 0  NaN  NaN  NaN
# 1  0.0  0.0  0.0
# 2  0.0  1.0  0.0
# 3  0.0  0.0  0.0
# 4  0.0  0.0  0.0
# 5  0.0  0.0  0.0
# 6  0.0  0.0  1.0
# 7  0.0  0.0  0.0
# 8  0.0  0.0  0.0
# 9  0.0  0.0  0.0
